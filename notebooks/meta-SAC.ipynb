# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0,'..')

import torch
from algo import core
from algo import sac as algo
from algo.utils import plot
import gym
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
env = gym.make('BipedalWalker-v3')
env.action_space.shape, env.observation_space.shape
# Out:
# /home/rob/.conda/envs/meta/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ((4,), (24,))

# %%
args = { 'env': 'BipedalWalker-v3', 'hid': 256, 
        'l':2, 'gamma':0.99, 'seed':0, 'epoch': 50, 
        'exp_name': 'sac'}

torch.set_num_threads(torch.get_num_threads())
algo.sac(lambda: gym.make(args['env']), actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), epochs=args['epoch'])
# Out:
# Logging data to /tmp/experiments/1616759952/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_fn":	"<function <lambda> at 0x7fd443407290>",
#     "epochs":	50,
#     "gamma":	0.99,
#     "logger":	{
#         "<algo.utils.logx.EpochLogger object at 0x7fd43de9e9d0>":	{
#             "epoch_dict":	{},
#             "exp_name":	null,
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/tmp/experiments/1616759952",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/tmp/experiments/1616759952/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{},
#     "lr":	0.001,
#     "max_ep_len":	1000,
# ...

# %%
# 
plot.make_plots(['/tmp/experiments/1616759952'], 
                values=['AverageTestEpRet', 'AverageEpRet', 'LossQ', 'LossPi', 'AverageQ2Vals', 'AverageQ1Vals'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Plotting from...
# ...
#
# /tmp/experiments/1616759952
#
# ...
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
