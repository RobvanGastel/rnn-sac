# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0,'..')

import torch
from algo import core
from algo import sac as algo
from algo.utils import plot
import gym
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
env = gym.make('Pendulum-v0')
env.action_space.shape, env.observation_space.shape
# Out:
# ((1,), (3,))

# %%
env = gym.make('BipedalWalker-v3')
env.action_space, env.observation_space
# Out:
# /home/rob/.conda/envs/meta/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (Box(-1.0, 1.0, (4,), float32), Box(-inf, inf, (24,), float32))

# %%
# Regular OpenAI SpinningUp SAC
plot.make_plots(['/home/rob/Git/meta-learners/algo/data/sac/sac_s42'], 
                values=['AverageTestEpRet', 'AverageEpRet', 'LossQ', 'LossPi', 
                        'AverageQ2Vals', 'AverageQ1Vals'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Plotting from...
# ...
#
# /home/rob/Git/meta-learners/algo/data/sac/sac_s42
#
# ...
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# Regular OpenAI SpinningUp SAC
plot.make_plots(['/home/rob/Git/meta-learners/meta-learners/algo/data/'], 
                values=['AverageTestEpRet', 'AverageEpRet', 'LossQ', 'LossPi', 
                        'AverageQ2Vals', 'AverageQ1Vals'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Plotting from...
# ...
#
# /home/rob/Git/meta-learners/meta-learners/algo/data/
#
# ...
# Could not read from /home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC/LSTM_SAC_s0/progress.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# Regular OpenAI SpinningUp SAC
plot.make_plots([
                 '/home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC'], 
                values=['AverageTestEpRet', 'AverageEpRet', 'LossQ', 'LossPi', 
                        'AverageQ2Vals', 'AverageQ1Vals'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Plotting from...
# ...
#
# /home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC
# /home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC_0.0_0.003
# /home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC_0.2_0.001
# /home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC_0.2_0.003
#
# ...
# Could not read from /home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC/LSTM_SAC_s0/progress.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
