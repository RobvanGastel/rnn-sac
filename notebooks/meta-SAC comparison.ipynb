# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0,'..')

import torch
from algo import core
from algo import sac as algo
from algo.utils import plot
import gym
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
env = gym.make('Pendulum-v0')
env.action_space.shape, env.observation_space.shape
# Out:
# ((1,), (3,))

# %%
env = gym.make('BipedalWalker-v3')
env.action_space, env.observation_space
# Out:
# (Box(-1.0, 1.0, (4,), float32), Box(-inf, inf, (24,), float32))

# %%
# Regular OpenAI SpinningUp SAC
plot.make_plots(['/home/rob/Git/meta-learners/algo/data/sac/sac_s42'], 
                values=['AverageTestEpRet', 'AverageEpRet', 'LossQ', 'LossPi', 
                        'AverageQ2Vals', 'AverageQ1Vals'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Plotting from...
# ==================================================
#
# /home/rob/Git/meta-learners/algo/data/sac/sac_s42
#
# ==================================================
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# Regular OpenAI SpinningUp SAC
plot.make_plots(['/home/rob/Git/meta-learners/algo/data/rnn_sac/rnn_sac_s42'], 
                values=['AverageTestEpRet', 'AverageEpRet', 'LossQ', 'LossPi', 
                        'AverageQ2Vals', 'AverageQ1Vals'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# Plotting from...
# ==================================================
#
# /home/rob/Git/meta-learners/algo/data/rnn_sac/rnn_sac_s42
#
# ==================================================
# Could not read from /home/rob/Git/meta-learners/algo/data/rnn_sac/rnn_sac_s42/progress.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-54f41403c3b2> in <module>
#       4                         'AverageQ2Vals', 'AverageQ1Vals'],
#       5                 xaxis='Epoch',
# ----> 6                 smooth=0.6)
#
# ~/Git/meta-learners/algo/utils/plot.py in make_plots(all_logdirs, legend, xaxis, values, count, font_scale, smooth, select, exclude, estimator)
#     164         plt.figure()
#     165         plot_data(data, xaxis=xaxis, value=value, condition=condition,
# --> 166                   smooth=smooth, estimator=estimator)
#     167     plt.show()
#     168
#
# ~/Git/meta-learners/algo/utils/plot.py in plot_data(data, xaxis, value, condition, smooth, **kwargs)
#      30
#      31     if isinstance(data, list):
# ---> 32         data = pd.concat(data, ignore_index=True)
#      33     sns.set(style="darkgrid", font_scale=1.5)
#      34     # sns.tsplot(data=data, time=xaxis, value=value, unit="Unit", condition=condition, ci='sd', **kwargs)
#
# ~/.conda/envs/meta/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/.conda/envs/meta/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     327
#     328         if len(objs) == 0:
# --> 329             raise ValueError("No objects to concatenate")
#     330
#     331         if keys is None:
#
# ValueError: No objects to concatenate
