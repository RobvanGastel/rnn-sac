# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0,'..')
sys.path.insert(0,'../meta-learners')

import torch
from algo import core
from algo import sac as algo
from algo.utils import plot
import gym

# %%
env = gym.make('Pendulum-v0')
env.action_space.shape, env.observation_space.shape
# Out:
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# ((1,), (3,))

# %%
env = gym.make('BipedalWalker-v2')
env.action_space, env.observation_space
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (Box(4,), Box(24,))

# %% [markdown]
# ### Comparison of LSTM SAC and SAC on the Pendulum task

# %%
# Regular OpenAI SpinningUp SAC
plot.make_plots(['/home/rob/Git/meta-learners/meta-learners/algo/data/SAC_Pendulum', 
                 '/home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC_Pendulum'], 
                values=['AverageTestEpRet', 'AverageEpRet', 'LossQ', 'LossPi', 
                        'AverageQ2Vals', 'AverageQ1Vals'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# Plotting from...
# ==================================================
#
#
# ==================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-71cffc4b2edd> in <module>
#       5                         'AverageQ2Vals', 'AverageQ1Vals'],
#       6                 xaxis='Epoch',
# ----> 7                 smooth=0.6)
#
# ~/Git/meta-learners/meta-learners/algo/utils/plot.py in make_plots(all_logdirs, legend, xaxis, values, count, font_scale, smooth, select, exclude, estimator)
#     165         plt.figure()
#     166         plot_data(data, xaxis=xaxis, value=value, condition=condition,
# --> 167                   smooth=smooth, estimator=estimator)
#     168     plt.show()
#     169
#
# ~/Git/meta-learners/meta-learners/algo/utils/plot.py in plot_data(data, xaxis, value, condition, smooth, **kwargs)
#      30
#      31     if isinstance(data, list):
# ---> 32         data = pd.concat(data, ignore_index=True)
#      33     sns.set(style="darkgrid", font_scale=1.5)
#      34     sns.tsplot(data=data, time=xaxis, value=value, unit="Unit",
#
# ~/.conda/envs/temp/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/.conda/envs/temp/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     327
#     328         if len(objs) == 0:
# --> 329             raise ValueError("No objects to concatenate")
#     330
#     331         if keys is None:
#
# ValueError: No objects to concatenate

# %% [markdown]
# ### Comparing all results on LSTM SAC on the Pendulum task

# %%
# Visualizing RNN policy models
plot.make_plots([
                 '/home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC'], 
                values=['AverageTestEpRet', 'AverageEpRet', 'LossQ', 'LossPi', 
                        'AverageQ2Vals', 'AverageQ1Vals'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# Plotting from...
# ==================================================
#
# /home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC_0.0_0.003
# /home/rob/Git/meta-learners/meta-learners/algo/data/LSTM_SAC_0.2_0.003
#
# ==================================================
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Comparing all results on Bipedal Walker RL$^2$

# %% [markdown]
# The distribution $\mathcal{D}$ of tasks $\mathcal{T_i}$ consists of the BipedalWalker and HardcoreBipedalWalker. Hence, from $\mathcal{D}$ is sampled during training and testing.

# %%
plot.make_plots([
                 '/home/rob/Git/meta-learners/meta-learners/algo/data/RL2'],
                values=['AverageTestEpRet', 'AverageEpRet'], 
                xaxis='Epoch',
                smooth=0.6)
# Out:
# Plotting from...
# ==================================================
#
# /home/rob/Git/meta-learners/meta-learners/algo/data/RL2_SAC_0.2_0.001
#
# ==================================================
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/rob/.conda/envs/temp/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
